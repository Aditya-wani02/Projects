# %% [markdown]
# ## import the data using api and convert it into a csv file

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=d7a0f78cf708fe1d2c4d5adefa8c928d&language=en-US&page=1')

# %%
pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
# Out:
#         id                                          title  \
# 0      238                                  The Godfather
# 1      278                       The Shawshank Redemption
# 2   569094            Spider-Man: Across the Spider-Verse
# 3      240                          The Godfather Part II
# 4      424                               Schindler's List
# 5    19404                    Dilwale Dulhania Le Jayenge
# 6      129                                  Spirited Away
# 7      389                                   12 Angry Men
# 8   372058                                     Your Name.
# 9   496243                                       Parasite
# 10     155                                The Dark Knight
# 11     497                                 The Green Mile
# 12  772071                               Cuando Sea Joven
# 13     680                                   Pulp Fiction
# 14      13                                   Forrest Gump
# ...

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=d7a0f78cf708fe1d2c4d5adefa8c928d&language=en-US&page={}'.format(i))
    temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df=df.append(temp_df,ignore_index=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11304\4274520446.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_11304\4274520446.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_11304\4274520446.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_11304\4274520446.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# ...

# %%
df.shape
# Out:
# (8560, 7)

# %% [markdown]
# ## saving as a csv file

# %%
df.to_csv('movies_data.csv')
